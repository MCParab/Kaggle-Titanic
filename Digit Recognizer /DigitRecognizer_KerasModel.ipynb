# %%
from keras.models import Sequential
from keras.utils import np_utils
from keras.layers.core import Dense, Activation, Dropout 

import pandas as pd
import numpy as np

# %%
#Read Data 
train=pd.read_csv('Data/train.csv')
labels=train.iloc[:,0].values.astype('int32')

X_train=(train.iloc[:,1:].values).astype('float32')
X_test=(pd.read_csv('Data/test.csv').values).astype('float32')

# %%
#convert list of df=pd.read_csv("keras-mlp.csv")labels to binary class matrix 
y_train = np_utils.to_categorical(labels)

# %%
#Preprocessing : divide by max and subtract by mean
scale=np.max(X_train)
X_train/=scale
X_test/=scale

mean=np.std(X_train)
X_train-=mean
X_test-=mean

# %%
y_train.shape[1]
# Out:
# 10

# %%
input_dim=X_train.shape[1]
nb_classes=y_train.shape[1]

# %%
#DDMLP
model=Sequential()

model.add(Dense(120,input_dim=input_dim))
model.add(Activation('relu'))
model.add(Dropout(0.15))

model.add(Dense(120))
model.add(Activation('relu'))
model.add(Dropout(0.15))

model.add(Dense(nb_classes))
model.add(Activation('softmax'))

# %%
#Use categorical cross entropy for the loss, and RMSprop as the optimizer
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
model.fit(X_train,y_train, epochs=10, batch_size=16, validation_split=0.1, verbose=2)
# Out:
# Train on 37800 samples, validate on 4200 samples
# Epoch 1/10
# 15s - loss: 0.3653 - acc: 0.8894 - val_loss: 0.1958 - val_acc: 0.9440
# Epoch 2/10
# 10s - loss: 0.2054 - acc: 0.9425 - val_loss: 0.1714 - val_acc: 0.9533
# Epoch 3/10
# 10s - loss: 0.1809 - acc: 0.9518 - val_loss: 0.1458 - val_acc: 0.9633
# Epoch 4/10
# 11s - loss: 0.1736 - acc: 0.9560 - val_loss: 0.1678 - val_acc: 0.9607
# Epoch 5/10
# 10s - loss: 0.1797 - acc: 0.9575 - val_loss: 0.1635 - val_acc: 0.9619
# Epoch 6/10
# 10s - loss: 0.1820 - acc: 0.9598 - val_loss: 0.1545 - val_acc: 0.9686
# Epoch 7/10
# 10s - loss: 0.1874 - acc: 0.9585 - val_loss: 0.1664 - val_acc: 0.9648
# Epoch 8/10
# 10s - loss: 0.1870 - acc: 0.9602 - val_loss: 0.1900 - val_acc: 0.9669
# Epoch 9/10
# 10s - loss: 0.1933 - acc: 0.9600 - val_loss: 0.1759 - val_acc: 0.9667
# Epoch 10/10
# 10s - loss: 0.1992 - acc: 0.9638 - val_loss: 0.2413 - val_acc: 0.9674

# %%
#Generating Test predictions 
preds=model.predict(X_test, verbose=0, batch_size=1)

# %%
def write_preds(preds, fname):
    pd.DataFrame({"ImageId": list(range(1,len(preds)+1)), "Label": np.argmax(preds, axis=1)}).to_csv(fname, index=False, header=True)

write_preds(preds, "keras-mlp.csv")

# %%
df= pd.read_csv('keras-mlp.csv')

# %%
df.head(100)
# Out:
#     ImageId  Label
# 0         1      2
# 1         2      0
# 2         3      9
# 3         4      9
# 4         5      3
# 5         6      7
# 6         7      0
# 7         8      3
# 8         9      0
# 9        10      3
# 10       11      5
# 11       12      7
# 12       13      4
# 13       14      0
# 14       15      4
# 15       16      3
# 16       17      3
# 17       18      1
# 18       19      9
# 19       20      0
# 20       21      9
# 21       22      1
# 22       23      1
# 23       24      5
# 24       25      7
# 25       26      4
# 26       27      2
# 27       28      7
# 28       29      4
# 29       30      7
# ..      ...    ...
# 70       71      6
# 71       72      5
# 72       73      8
# 73       74      8
# 74       75      2
# 75       76      8
# 76       77      9
# 77       78      9
# 78       79      2
# 79       80      3
# 80       81      5
# 81       82      9
# 82       83      1
# 83       84      0
# 84       85      9
# 85       86      2
# 86       87      4
# 87       88      3
# 88       89      6
# 89       90      7
# 90       91      2
# 91       92      0
# 92       93      6
# 93       94      6
# 94       95      1
# 95       96      4
# 96       97      3
# 97       98      9
# 98       99      7
# 99      100      4
#
# [100 rows x 2 columns]
